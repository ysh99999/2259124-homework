# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1     ,  
                out_channels=32     ,
                kernel_size=7      ,
                stride=1           ,
                padding=5          ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            
            nn.Conv2d( # ???
                in_channels=32     ,  
                out_channels=64     ,
                kernel_size=5      ,
                stride=1           ,
                padding=1          ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
         

        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0),-1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# c:\Users\86136\AppData\Local\Programs\Python\Python38\lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\86136\AppData\Local\Temp\ipykernel_10768\3018851415.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# c:\Users\86136\AppData\Local\Programs\Python\Python38\lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\86136\AppData\Local\Temp\ipykernel_10768\3018851415.py:75: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.222 ==========
# ========== 40 ===== ===== test accuracy is  0.338 ==========
# ========== 60 ===== ===== test accuracy is  0.494 ==========
# ========== 80 ===== ===== test accuracy is  0.534 ==========
# ========== 100 ===== ===== test accuracy is  0.62 ==========
# ========== 120 ===== ===== test accuracy is  0.604 ==========
# ========== 140 ===== ===== test accuracy is  0.636 ==========
# ========== 160 ===== ===== test accuracy is  0.708 ==========
# ========== 180 ===== ===== test accuracy is  0.712 ==========
# ========== 200 ===== ===== test accuracy is  0.73 ==========
# ========== 220 ===== ===== test accuracy is  0.756 ==========
# ========== 240 ===== ===== test accuracy is  0.774 ==========
# ========== 260 ===== ===== test accuracy is  0.818 ==========
# ========== 280 ===== ===== test accuracy is  0.826 ==========
# ========== 300 ===== ===== test accuracy is  0.864 ==========
# ========== 320 ===== ===== test accuracy is  0.84 ==========
# ========== 340 ===== ===== test accuracy is  0.88 ==========
# ========== 360 ===== ===== test accuracy is  0.88 ==========
# ========== 380 ===== ===== test accuracy is  0.87 ==========
# ========== 400 ===== ===== test accuracy is  0.868 ==========
# ========== 420 ===== ===== test accuracy is  0.876 ==========
# ========== 440 ===== ===== test accuracy is  0.892 ==========
# ========== 460 ===== ===== test accuracy is  0.902 ==========
# ========== 480 ===== ===== test accuracy is  0.904 ==========
# ========== 500 ===== ===== test accuracy is  0.908 ==========
# ========== 520 ===== ===== test accuracy is  0.914 ==========
# ========== 540 ===== ===== test accuracy is  0.906 ==========
# ========== 560 ===== ===== test accuracy is  0.9 ==========
# ========== 580 ===== ===== test accuracy is  0.92 ==========
# ========== 600 ===== ===== test accuracy is  0.92 ==========
# ========== 620 ===== ===== test accuracy is  0.916 ==========
# ========== 640 ===== ===== test accuracy is  0.914 ==========
# ========== 660 ===== ===== test accuracy is  0.914 ==========
# ========== 680 ===== ===== test accuracy is  0.93 ==========
# ========== 700 ===== ===== test accuracy is  0.92 ==========
# ========== 720 ===== ===== test accuracy is  0.94 ==========
# ========== 740 ===== ===== test accuracy is  0.924 ==========
# ========== 760 ===== ===== test accuracy is  0.936 ==========
# ========== 780 ===== ===== test accuracy is  0.918 ==========
# ========== 800 ===== ===== test accuracy is  0.926 ==========
# ========== 820 ===== ===== test accuracy is  0.928 ==========
# ========== 840 ===== ===== test accuracy is  0.932 ==========
# ========== 860 ===== ===== test accuracy is  0.932 ==========
# ========== 880 ===== ===== test accuracy is  0.934 ==========
# ========== 900 ===== ===== test accuracy is  0.934 ==========
# ========== 920 ===== ===== test accuracy is  0.932 ==========
# ========== 940 ===== ===== test accuracy is  0.946 ==========
# ========== 960 ===== ===== test accuracy is  0.936 ==========
# ========== 980 ===== ===== test accuracy is  0.948 ==========
# ========== 1000 ===== ===== test accuracy is  0.948 ==========
# ========== 1020 ===== ===== test accuracy is  0.946 ==========
# ========== 1040 ===== ===== test accuracy is  0.938 ==========
# ========== 1060 ===== ===== test accuracy is  0.944 ==========
# ========== 1080 ===== ===== test accuracy is  0.944 ==========
# ========== 1100 ===== ===== test accuracy is  0.932 ==========
# ========== 1120 ===== ===== test accuracy is  0.958 ==========
# ========== 1140 ===== ===== test accuracy is  0.95 ==========
# ========== 1160 ===== ===== test accuracy is  0.94 ==========
# ========== 1180 ===== ===== test accuracy is  0.942 ==========
# ========== 20 ===== ===== test accuracy is  0.94 ==========
# ========== 40 ===== ===== test accuracy is  0.948 ==========
# ========== 60 ===== ===== test accuracy is  0.956 ==========
# ========== 80 ===== ===== test accuracy is  0.946 ==========
# ========== 100 ===== ===== test accuracy is  0.958 ==========
# ========== 120 ===== ===== test accuracy is  0.956 ==========
# ========== 140 ===== ===== test accuracy is  0.95 ==========
# ========== 160 ===== ===== test accuracy is  0.944 ==========
# ========== 180 ===== ===== test accuracy is  0.954 ==========
# ========== 200 ===== ===== test accuracy is  0.938 ==========
# ========== 220 ===== ===== test accuracy is  0.952 ==========
# ========== 240 ===== ===== test accuracy is  0.954 ==========
# ========== 260 ===== ===== test accuracy is  0.958 ==========
# ========== 280 ===== ===== test accuracy is  0.95 ==========
# ========== 300 ===== ===== test accuracy is  0.94 ==========
# ========== 320 ===== ===== test accuracy is  0.96 ==========
# ========== 340 ===== ===== test accuracy is  0.968 ==========
# ========== 360 ===== ===== test accuracy is  0.964 ==========
# ========== 380 ===== ===== test accuracy is  0.964 ==========
# ========== 400 ===== ===== test accuracy is  0.958 ==========
# ========== 420 ===== ===== test accuracy is  0.956 ==========
# ========== 440 ===== ===== test accuracy is  0.952 ==========
# ========== 460 ===== ===== test accuracy is  0.962 ==========
# ========== 480 ===== ===== test accuracy is  0.948 ==========
# ========== 500 ===== ===== test accuracy is  0.952 ==========
# ========== 520 ===== ===== test accuracy is  0.95 ==========
# ========== 540 ===== ===== test accuracy is  0.944 ==========
# ========== 560 ===== ===== test accuracy is  0.954 ==========
# ========== 580 ===== ===== test accuracy is  0.954 ==========
# ========== 600 ===== ===== test accuracy is  0.958 ==========
# ========== 620 ===== ===== test accuracy is  0.958 ==========
# ========== 640 ===== ===== test accuracy is  0.96 ==========
# ========== 660 ===== ===== test accuracy is  0.964 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.966 ==========
# ========== 720 ===== ===== test accuracy is  0.964 ==========
# ========== 740 ===== ===== test accuracy is  0.952 ==========
# ========== 760 ===== ===== test accuracy is  0.962 ==========
# ========== 780 ===== ===== test accuracy is  0.966 ==========
# ========== 800 ===== ===== test accuracy is  0.962 ==========
# ========== 820 ===== ===== test accuracy is  0.952 ==========
# ========== 840 ===== ===== test accuracy is  0.97 ==========
# ========== 860 ===== ===== test accuracy is  0.962 ==========
# ========== 880 ===== ===== test accuracy is  0.954 ==========
# ========== 900 ===== ===== test accuracy is  0.958 ==========
# ========== 920 ===== ===== test accuracy is  0.966 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.966 ==========
# ========== 980 ===== ===== test accuracy is  0.972 ==========
# ========== 1000 ===== ===== test accuracy is  0.956 ==========
# ========== 1020 ===== ===== test accuracy is  0.962 ==========
# ========== 1040 ===== ===== test accuracy is  0.964 ==========
# ========== 1060 ===== ===== test accuracy is  0.97 ==========
# ========== 1080 ===== ===== test accuracy is  0.972 ==========
# ========== 1100 ===== ===== test accuracy is  0.966 ==========
# ========== 1120 ===== ===== test accuracy is  0.964 ==========
# ========== 1140 ===== ===== test accuracy is  0.97 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.968 ==========
# ========== 20 ===== ===== test accuracy is  0.97 ==========
# ========== 40 ===== ===== test accuracy is  0.966 ==========
# ========== 60 ===== ===== test accuracy is  0.972 ==========
# ========== 80 ===== ===== test accuracy is  0.956 ==========
# ========== 100 ===== ===== test accuracy is  0.962 ==========
# ========== 120 ===== ===== test accuracy is  0.968 ==========
# ========== 140 ===== ===== test accuracy is  0.97 ==========
# ========== 160 ===== ===== test accuracy is  0.966 ==========
# ========== 180 ===== ===== test accuracy is  0.962 ==========
# ========== 200 ===== ===== test accuracy is  0.962 ==========
# ========== 220 ===== ===== test accuracy is  0.96 ==========
# ========== 240 ===== ===== test accuracy is  0.976 ==========
# ========== 260 ===== ===== test accuracy is  0.966 ==========
# ========== 280 ===== ===== test accuracy is  0.968 ==========
# ========== 300 ===== ===== test accuracy is  0.966 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.958 ==========
# ========== 360 ===== ===== test accuracy is  0.976 ==========
# ========== 380 ===== ===== test accuracy is  0.966 ==========
# ========== 400 ===== ===== test accuracy is  0.956 ==========
# ========== 420 ===== ===== test accuracy is  0.97 ==========
# ========== 440 ===== ===== test accuracy is  0.958 ==========
# ========== 460 ===== ===== test accuracy is  0.968 ==========
# ========== 480 ===== ===== test accuracy is  0.968 ==========
# ========== 500 ===== ===== test accuracy is  0.966 ==========
# ========== 520 ===== ===== test accuracy is  0.98 ==========
# ========== 540 ===== ===== test accuracy is  0.974 ==========
# ========== 560 ===== ===== test accuracy is  0.974 ==========
# ========== 580 ===== ===== test accuracy is  0.974 ==========
# ========== 600 ===== ===== test accuracy is  0.968 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.966 ==========
# ========== 660 ===== ===== test accuracy is  0.974 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.966 ==========
# ========== 740 ===== ===== test accuracy is  0.972 ==========
# ========== 760 ===== ===== test accuracy is  0.97 ==========
# ========== 780 ===== ===== test accuracy is  0.966 ==========
# ========== 800 ===== ===== test accuracy is  0.974 ==========
# ========== 820 ===== ===== test accuracy is  0.968 ==========
# ========== 840 ===== ===== test accuracy is  0.97 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.972 ==========
# ========== 900 ===== ===== test accuracy is  0.98 ==========
# ========== 920 ===== ===== test accuracy is  0.98 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.966 ==========
# ========== 980 ===== ===== test accuracy is  0.962 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.972 ==========
# ========== 1040 ===== ===== test accuracy is  0.982 ==========
